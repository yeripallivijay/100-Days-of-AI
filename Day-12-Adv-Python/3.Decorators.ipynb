# %%
def welcome():
    return "Welcome to the 100 days of Data Science journey with vijay"

welcome()
# Out:
# 'Welcome to the 100 days of Data Science journey with vijay'

# %%
wel = welcome
print(wel())
del welcome
print(wel())
# Out:
# Welcome to the 100 days of Data Science journey with vijay
# Welcome to the 100 days of Data Science journey with vijay

# %%
def main_welcome(msg):
    def sub_welcome_method():
        print(msg)
        print("Consistency and Discipline is important")
    return sub_welcome_method()

main_welcome("Welcome everyone")
# Out:
# Welcome everyone
# Consistency and Discipline is important

# %%
def main_welcome(msg,lst):
    def sub_welcome_method():
        print(msg,lst)
        print("Consistency and Discipline is important")
    return sub_welcome_method()

main_welcome(len,[1,2,3,4,5])
# Out:
# <built-in function len> [1, 2, 3, 4, 5]
# Consistency and Discipline is important

# %%
def my_decorator(func):
    def wrapper():
        print("Something is happening before the function is called.")
        func()
        print("Something is happening after the function is called.")
    return wrapper

# %%
@my_decorator
def say_hello():
    print("Hello!")

say_hello()
# Out:
# Something is happening before the function is called.
# Hello!
# Something is happening after the function is called.
