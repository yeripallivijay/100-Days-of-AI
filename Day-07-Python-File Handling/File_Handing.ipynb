# %%
print("File Handlings")
# Out:
# File Handlings

# %%
with open('source.txt','r') as  file:
    content = file.read()
    print(content)
# Out:
# Hello Everyone?
# welcome to the day 6 AI and Data science journey
# By Vijay

# %%
with open('source.txt','r') as file:
    for line in file:
        print(line.strip())
# Out:
# Hello Everyone?
# welcome to the day 6 AI and Data science journey
# By Vijay

# %%
with open ('newly.txt','w') as file:
    file.write("Newly added")

# %%
data = b'\x00\x01\x02\x03\x04'
with open('example.bin', 'wb') as file:
    file.write(data)

# %%
with open('example.bin', 'rb') as file:
    content = file.read()
    print(content)
# Out:
# b'\x00\x01\x02\x03\x04'

# %%
with open('source.txt','r') as file:
    content = file.read()
    print(content)

with open('destination.txt','w') as file:
    file.write(content)
    print(content)
# Out:
# Hello Everyone?
# welcome to the day 6 AI and Data science journey
# By Vijay
# Hello Everyone?
# welcome to the day 6 AI and Data science journey
# By Vijay

# %%
# Real world use of Files

def count_text_file(file_info):
    with open(file_info,'r') as file:
        lines = file.readlines()
        line_count = len(lines)
        word_count = sum(len(line.split()) for line in lines)
        char_count = sum(len(line)for line in lines)
    return line_count,word_count,char_count


file_info = 'destination.txt'
lines,words,characters = count_text_file(file_info)


print(f"Lines:{lines},Words:{words},Characters:{characters}")
print(content)
# Out:
# Lines:3,Words:14,Characters:73
# Hello Everyone?
# welcome to the day 6 AI and Data science journey
# By Vijay
