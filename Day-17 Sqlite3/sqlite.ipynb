# %%
import sqlite3

# %%
connection = sqlite3.connect('new.db')
connection

# %%
cursor = connection.cursor()

# %%
cursor.execute('''
Create Table If Not Exists Employees(
               id Integer Primary Key,
               name Text Not Null,
               age Integer,
               department Text
               )
''')
connection.commit()

# %%
cursor.execute('''
Select * from Employees
''')

# %%
cursor.execute('''
Insert Into Employees(name,age,department)
               values('Vijay',25,'Data Scientist')
''')
cursor.execute('''
Insert Into Employees(name,age,department)
               values('Arjun',24,'Data-Analyst')
''')
cursor.execute('''
Insert Into Employees (name,age,department)
               values('Sony',35,'F1 Racer')
''')
connection.commit()

# %%
cursor.execute('Select * from Employees')
rows=cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Vijay', 25, 'Data Scientist')
# (2, 'Arjun', 24, 'Data-Analyst')
# (3, 'Vijay', 25, 'Data Scientist')
# (4, 'Arjun', 24, 'Data-Analyst')
# (5, 'Sony', 35, 'F1 Racer')
# (6, 'Vijay', 25, 'Data Scientist')
# (7, 'Arjun', 24, 'Data-Analyst')
# (8, 'Sony', 35, 'F1 Racer')

# %%
#Delete the data 

cursor.execute('''
Delete from Employees
               where name = 'Sony'
''')
connection.commit()

# %%
cursor.execute('Select * from Employees')
rows=cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Vijay', 25, 'Data Scientist')
# (2, 'Arjun', 24, 'Data-Analyst')
# (3, 'Vijay', 25, 'Data Scientist')
# (4, 'Arjun', 24, 'Data-Analyst')
# (6, 'Vijay', 25, 'Data Scientist')
# (7, 'Arjun', 24, 'Data-Analyst')

# %%
connection = sqlite3.connect('sales_data.db')
cursor = connection.cursor()

cursor.execute('''
CREATE TABLE IF NOT EXISTS sales (
               id INTEGER PRIMARY KEY,
               date TEXT NOT NULL,
               product TEST NOT NULL,
               sales INTEGER,
               region TEXT
               )
''')

sales_data = [
    ('2023-01-01', 'Product1', 100, 'North'),
    ('2023-01-02', 'Product2', 200, 'South'),
    ('2023-01-03', 'Product1', 150, 'East'),
    ('2023-01-04', 'Product3', 250, 'West'),
    ('2023-01-05', 'Product2', 300, 'North')
]
cursor.executemany('''
Insert into sales(date,product,sales,region)
                   values(?,?,?,?)
''',sales_data)

connection.commit()

# %%
cursor.execute('SELECT * FROM sales')
rows = cursor.fetchall()


for row in rows:
    print(row)
# Out:
# (1, '2023-01-01', 'Product1', 100, 'North')
# (2, '2023-01-02', 'Product2', 200, 'South')
# (3, '2023-01-03', 'Product1', 150, 'East')
# (4, '2023-01-04', 'Product3', 250, 'West')
# (5, '2023-01-05', 'Product2', 300, 'North')
# (6, '2023-01-01', 'Product1', 100, 'North')
# (7, '2023-01-02', 'Product2', 200, 'South')
# (8, '2023-01-03', 'Product1', 150, 'East')
# (9, '2023-01-04', 'Product3', 250, 'West')
# (10, '2023-01-05', 'Product2', 300, 'North')

# %%
connection.close()
