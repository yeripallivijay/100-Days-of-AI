# %%
class Car:
    pass

audi = Car()
audi.windows = 4
bmw = Car()

print(type(audi))
print(audi)
print(bmw)
print(audi.windows)
dir(audi)
# Out:
# <class '__main__.Car'>
# <__main__.Car object at 0x0000016022B50830>
# <__main__.Car object at 0x0000016022B48A50>
# 4
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'windows']

# %%
class Dog:

    #constructor
    def __init__(self,name,age):
        self.name=name
        self.age=age

#objects
dog1 = Dog("Ammu",3)
print(dog1)
print(dog1.name)
print(dog1.age)

dog2 = Dog("Lucy",5)
print(dog2)
print(dog2.name)
print(dog2.age)
# Out:
# <__main__.Dog object at 0x0000016022B530E0>
# Ammu
# 3
# <__main__.Dog object at 0x0000016022B4A210>
# Lucy
# 5

# %%
class Dog:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    
    def bark(self):
        print(f"{self.name} says woof")

dog1 = Dog("Ammu",3)

dog1.bark()

dog2 = Dog("Lucy",5)
dog2.bark()
# Out:
# Ammu says woof
# Lucy says woof

# %%
#Example of Bank Account

class BankAccount:
    def __init__(self,owner,balance=0):
        self.owner=owner
        self.balance=balance

    def deposit(self,amount):
        self.balance+=amount
        print(f"{amount}  is deposited.New Balance is {self.balance}")

    def withdraw(self,amount):
        if amount>self.balance:
            print("Insufficient balance")
        else:
            self.balance-=amount
            print(f"{amount} is withdrawn. New Balance is {self.balance}")

    def get_balance(self):
        return self.balance
    
account = BankAccount("vijay",5000)
print(account.balance)
account.deposit(500)
account.withdraw(1000)
print(account.get_balance())
# Out:
# 5000
# 500  is deposited.New Balance is 5500
# 1000 is withdrawn. New Balance is 4500
# 4500
