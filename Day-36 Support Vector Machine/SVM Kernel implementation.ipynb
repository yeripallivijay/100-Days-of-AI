#        -9.66258107, -9.63508769, -9.60645359, -9.57666854, -9.54572176,
#        -9.51360192, -9.4802971 , -9.44579475, -9.41008171, -9.37314414,
#        -9.3349675 , -9.29553652, -9.25483518, -9.21284664, -9.16955321,
#        -9.12493632, -9.07897646, -9.03165312, -8.98294476, -8.93282873,
#        -8.88128118, -8.82827705, -8.77378994, -8.71779204, -8.66025404])

# %%
x1 = np.linspace(-5.0, 5.0, 100)
y1 = np.sqrt(5**2 - x1**2)
y1=np.hstack([y1,-y1])
x1=np.hstack([x1,-x1])

# %%
plt.scatter(y,x)
plt.scatter(y1,x1)

# %%
np.vstack([y,x]).T
# Out:
# array([[ 8.66025404, -5.        ],
#        [ 8.71779204, -4.8989899 ],
#        [ 8.77378994, -4.7979798 ],
#        [ 8.82827705, -4.6969697 ],
#        [ 8.88128118, -4.5959596 ],
#        [ 8.93282873, -4.49494949],
#        [ 8.98294476, -4.39393939],
#        [ 9.03165312, -4.29292929],
#        [ 9.07897646, -4.19191919],
#        [ 9.12493632, -4.09090909],
#        [ 9.16955321, -3.98989899],
#        [ 9.21284664, -3.88888889],
#        [ 9.25483518, -3.78787879],
#        [ 9.29553652, -3.68686869],
#        [ 9.3349675 , -3.58585859],
#        [ 9.37314414, -3.48484848],
#        [ 9.41008171, -3.38383838],
#        [ 9.44579475, -3.28282828],
#        [ 9.4802971 , -3.18181818],
#        [ 9.51360192, -3.08080808],
#        [ 9.54572176, -2.97979798],
#        [ 9.57666854, -2.87878788],
#        [ 9.60645359, -2.77777778],
#        [ 9.63508769, -2.67676768],
#        [ 9.66258107, -2.57575758],
#        [ 9.68894344, -2.47474747],
#        [ 9.714184  , -2.37373737],
#        [ 9.73831149, -2.27272727],
#        [ 9.76133416, -2.17171717],
#        [ 9.7832598 , -2.07070707],
#        [ 9.80409577, -1.96969697],
#        [ 9.82384901, -1.86868687],
#        [ 9.84252604, -1.76767677],
#        [ 9.86013297, -1.66666667],
#        [ 9.87667553, -1.56565657],
#        [ 9.89215905, -1.46464646],
#        [ 9.90658851, -1.36363636],
#        [ 9.91996849, -1.26262626],
#        [ 9.93230325, -1.16161616],
#        [ 9.94359667, -1.06060606],
#        [ 9.9538523 , -0.95959596],
#        [ 9.96307334, -0.85858586],
#        [ 9.97126266, -0.75757576],
#        [ 9.9784228 , -0.65656566],
#        [ 9.98455598, -0.55555556],
#        [ 9.98966408, -0.45454545],
#        [ 9.99374868, -0.35353535],
#        [ 9.99681104, -0.25252525],
#        [ 9.99885209, -0.15151515],
#        [ 9.99987246, -0.05050505],
#        [ 9.99987246,  0.05050505],
#        [ 9.99885209,  0.15151515],
#        [ 9.99681104,  0.25252525],
#        [ 9.99374868,  0.35353535],
#        [ 9.98966408,  0.45454545],
#        [ 9.98455598,  0.55555556],
#        [ 9.9784228 ,  0.65656566],
#        [ 9.97126266,  0.75757576],
#        [ 9.96307334,  0.85858586],
#        [ 9.9538523 ,  0.95959596],
#        [ 9.94359667,  1.06060606],
#        [ 9.93230325,  1.16161616],
#        [ 9.91996849,  1.26262626],
#        [ 9.90658851,  1.36363636],
#        [ 9.89215905,  1.46464646],
#        [ 9.87667553,  1.56565657],
#        [ 9.86013297,  1.66666667],
#        [ 9.84252604,  1.76767677],
#        [ 9.82384901,  1.86868687],
#        [ 9.80409577,  1.96969697],
#        [ 9.7832598 ,  2.07070707],
#        [ 9.76133416,  2.17171717],
#        [ 9.73831149,  2.27272727],
#        [ 9.714184  ,  2.37373737],
#        [ 9.68894344,  2.47474747],
#        [ 9.66258107,  2.57575758],
#        [ 9.63508769,  2.67676768],
#        [ 9.60645359,  2.77777778],
#        [ 9.57666854,  2.87878788],
#        [ 9.54572176,  2.97979798],
#        [ 9.51360192,  3.08080808],
#        [ 9.4802971 ,  3.18181818],
#        [ 9.44579475,  3.28282828],
#        [ 9.41008171,  3.38383838],
#        [ 9.37314414,  3.48484848],
#        [ 9.3349675 ,  3.58585859],
#        [ 9.29553652,  3.68686869],
#        [ 9.25483518,  3.78787879],
#        [ 9.21284664,  3.88888889],
#        [ 9.16955321,  3.98989899],
#        [ 9.12493632,  4.09090909],
#        [ 9.07897646,  4.19191919],
#        [ 9.03165312,  4.29292929],
#        [ 8.98294476,  4.39393939],
#        [ 8.93282873,  4.49494949],
#        [ 8.88128118,  4.5959596 ],
#        [ 8.82827705,  4.6969697 ],
#        [ 8.77378994,  4.7979798 ],
#        [ 8.71779204,  4.8989899 ],
#        [ 8.66025404,  5.        ],
#        [-8.66025404,  5.        ],
#        [-8.71779204,  4.8989899 ],
#        [-8.77378994,  4.7979798 ],
#        [-8.82827705,  4.6969697 ],
#        [-8.88128118,  4.5959596 ],
#        [-8.93282873,  4.49494949],
#        [-8.98294476,  4.39393939],
#        [-9.03165312,  4.29292929],
#        [-9.07897646,  4.19191919],
#        [-9.12493632,  4.09090909],
#        [-9.16955321,  3.98989899],
#        [-9.21284664,  3.88888889],
#        [-9.25483518,  3.78787879],
#        [-9.29553652,  3.68686869],
#        [-9.3349675 ,  3.58585859],
#        [-9.37314414,  3.48484848],
#        [-9.41008171,  3.38383838],
#        [-9.44579475,  3.28282828],
#        [-9.4802971 ,  3.18181818],
#        [-9.51360192,  3.08080808],
#        [-9.54572176,  2.97979798],
#        [-9.57666854,  2.87878788],
#        [-9.60645359,  2.77777778],
#        [-9.63508769,  2.67676768],
#        [-9.66258107,  2.57575758],
#        [-9.68894344,  2.47474747],
#        [-9.714184  ,  2.37373737],
#        [-9.73831149,  2.27272727],
#        [-9.76133416,  2.17171717],
#        [-9.7832598 ,  2.07070707],
#        [-9.80409577,  1.96969697],
#        [-9.82384901,  1.86868687],
#        [-9.84252604,  1.76767677],
#        [-9.86013297,  1.66666667],
#        [-9.87667553,  1.56565657],
#        [-9.89215905,  1.46464646],
#        [-9.90658851,  1.36363636],
#        [-9.91996849,  1.26262626],
#        [-9.93230325,  1.16161616],
#        [-9.94359667,  1.06060606],
#        [-9.9538523 ,  0.95959596],
#        [-9.96307334,  0.85858586],
#        [-9.97126266,  0.75757576],
#        [-9.9784228 ,  0.65656566],
#        [-9.98455598,  0.55555556],
#        [-9.98966408,  0.45454545],
#        [-9.99374868,  0.35353535],
#        [-9.99681104,  0.25252525],
#        [-9.99885209,  0.15151515],
#        [-9.99987246,  0.05050505],
#        [-9.99987246, -0.05050505],
#        [-9.99885209, -0.15151515],
#        [-9.99681104, -0.25252525],
#        [-9.99374868, -0.35353535],
#        [-9.98966408, -0.45454545],
#        [-9.98455598, -0.55555556],
#        [-9.9784228 , -0.65656566],
#        [-9.97126266, -0.75757576],
#        [-9.96307334, -0.85858586],
#        [-9.9538523 , -0.95959596],
#        [-9.94359667, -1.06060606],
#        [-9.93230325, -1.16161616],
#        [-9.91996849, -1.26262626],
#        [-9.90658851, -1.36363636],
#        [-9.89215905, -1.46464646],
#        [-9.87667553, -1.56565657],
#        [-9.86013297, -1.66666667],
#        [-9.84252604, -1.76767677],
#        [-9.82384901, -1.86868687],
#        [-9.80409577, -1.96969697],
#        [-9.7832598 , -2.07070707],
#        [-9.76133416, -2.17171717],
#        [-9.73831149, -2.27272727],
#        [-9.714184  , -2.37373737],
#        [-9.68894344, -2.47474747],
#        [-9.66258107, -2.57575758],
#        [-9.63508769, -2.67676768],
#        [-9.60645359, -2.77777778],
#        [-9.57666854, -2.87878788],
#        [-9.54572176, -2.97979798],
#        [-9.51360192, -3.08080808],
#        [-9.4802971 , -3.18181818],
#        [-9.44579475, -3.28282828],
#        [-9.41008171, -3.38383838],
#        [-9.37314414, -3.48484848],
#        [-9.3349675 , -3.58585859],
#        [-9.29553652, -3.68686869],
#        [-9.25483518, -3.78787879],
#        [-9.21284664, -3.88888889],
#        [-9.16955321, -3.98989899],
#        [-9.12493632, -4.09090909],
#        [-9.07897646, -4.19191919],
#        [-9.03165312, -4.29292929],
#        [-8.98294476, -4.39393939],
#        [-8.93282873, -4.49494949],
#        [-8.88128118, -4.5959596 ],
#        [-8.82827705, -4.6969697 ],
#        [-8.77378994, -4.7979798 ],
#        [-8.71779204, -4.8989899 ],
#        [-8.66025404, -5.        ]])

# %%
import pandas as pd
df1=pd.DataFrame(
    np.vstack([y,x]).T,
    columns=['X1','X2']
)
df1['Y']=0
df2=pd.DataFrame(
    np.vstack([y1,x1]).T,
    columns=['X1','X2']
)
df2['Y']=1
df = pd.concat([df1,df2])
df.head(5)
# Out:
#          X1       X2  Y
# 0  8.660254 -5.00000  0
# 1  8.717792 -4.89899  0
# 2  8.773790 -4.79798  0
# 3  8.828277 -4.69697  0
# 4  8.881281 -4.59596  0

# %%
df.tail()
# Out:
#            X1       X2  Y
# 195 -1.969049 -4.59596  1
# 196 -1.714198 -4.69697  1
# 197 -1.406908 -4.79798  1
# 198 -0.999949 -4.89899  1
# 199 -0.000000 -5.00000  1

# %%
### Independent and Dependent features
X = df.iloc[:, :2]  
y = df.Y

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 195    1
# 196    1
# 197    1
# 198    1
# 199    1
# Name: Y, Length: 400, dtype: int64

# %%
## Split the dataset into train and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)

# %%
y_train
# Out:
# 50     1
# 63     0
# 112    1
# 159    0
# 83     1
#       ..
# 123    1
# 192    0
# 117    0
# 47     0
# 172    0
# Name: Y, Length: 300, dtype: int64

# %% [markdown]
# #### Polynomial Kernel
# K(x,y)=(x^t * y + c)^d

# %%
#X1,X2,X1_square,X2_square,X1*X2
df['X1_Square']= df['X1']**2
df['X2_Square']= df['X2']**2
df['X1*X2'] = (df['X1'] *df['X2'])
df.head()
# Out:
#          X1       X2  Y  X1_Square  X2_Square      X1*X2
# 0  8.660254 -5.00000  0  75.000000  25.000000 -43.301270
# 1  8.717792 -4.89899  0  75.999898  24.000102 -42.708375
# 2  8.773790 -4.79798  0  76.979390  23.020610 -42.096467
# 3  8.828277 -4.69697  0  77.938476  22.061524 -41.466150
# 4  8.881281 -4.59596  0  78.877155  21.122845 -40.818009

# %%
### Independent and Dependent features
X = df[['X1','X2','X1_Square','X2_Square','X1*X2']]
y = df['Y']

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 195    1
# 196    1
# 197    1
# 198    1
# 199    1
# Name: Y, Length: 400, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(
X,
y,
test_size = 0.25, 
random_state = 0
)

# %%
X_train
# Out:
#            X1        X2  X1_Square  X2_Square      X1*X2
# 50   4.999745  0.050505  24.997449   0.002551   0.252512
# 63   9.906589  1.363636  98.140496   1.859504  13.508984
# 112 -3.263736  3.787879  10.651974  14.348026 -12.362637
# 159 -9.953852 -0.959596  99.079176   0.920824   9.551676
# 83   3.680983  3.383838  13.549638  11.450362  12.455852
# ..        ...       ...        ...        ...        ...
# 123 -4.223140  2.676768  17.834915   7.165085 -11.304366
# 192 -9.031653 -4.292929  81.570758  18.429242  38.772248
# 117 -9.445795  3.282828  89.223038  10.776962 -31.008922
# 47   9.996811 -0.252525  99.936231   0.063769  -2.524447
# 172 -9.738311 -2.272727  94.834711   5.165289  22.132526
#
# [300 rows x 5 columns]

# %%
# !pip install nbformat
# Out:
# Requirement already satisfied: nbformat in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from nbformat) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.5.1)

# %%
# !pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (7.1.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from ipykernel) (1.8.19)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from ipykernel) (9.9.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from ipykernel) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from ipykernel) (25.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from ipykernel) (7.2.1)
# Requirement already satisfied: pyzmq>=25 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from ipykernel) (6.5.4)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from jupyter-client>=8.0.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.5.1)
# Requirement already satisfied: six>=1.5 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)

# %%
pip install --upgrade nbformat
# Out:
# Requirement already satisfied: nbformat in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from nbformat) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\vijay\desktop\day-36 support vector machine\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px

fig = px.scatter_3d(
    df,
    x='X1', 
    y='X2', 
    z='X1*X2',
    color='Y')

# %%
fig.show()

# %%
fig = px.scatter_3d(
    df, 
    x='X1_Square', 
    y='X1_Square', 
    z='X1*X2',
    color='Y'
    )
fig.show()

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
classifier = SVC(kernel="linear")
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
classifier = SVC(kernel="poly")
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
classifier = SVC(kernel="rbf")
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
classifier = SVC(kernel="sigmoid")
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 1.0
