# %% [markdown]
# ## Natural Language Processing(NLP)

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in .\venv\Lib\site-packages (3.9.2)
# Requirement already satisfied: click in .\venv\Lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in C:\Users\VIJAY\AppData\Roaming\Python\Python313\site-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in .\venv\Lib\site-packages (from nltk) (2026.1.15)
# Requirement already satisfied: tqdm in .\venv\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in .\venv\Lib\site-packages (from click->nltk) (0.4.6)

# %%
corpus = """ 
Hello Everyone,Welcome to the 100 Day's of Data scientist journey,
Stared the learning of the NLP.
"""

# %%
print(corpus)
# Out:
#
# Hello Everyone,Welcome to the 100 Day's of Data scientist journey,
# Stared the learning of the NLP.

# %%
# Tokenization => Converting Sentence to Paragraphs
from nltk.tokenize import sent_tokenize

documents = sent_tokenize(corpus)
print(type(documents))

for sentence in documents:
    print(sentence)
# Out:
# <class 'list'>
#
# Hello Everyone,Welcome to the 100 Day's of Data scientist journey,
# Stared the learning of the NLP.

# %%
# Paragraph-->words
# Sentence--.words
from nltk.tokenize import word_tokenize

# word_tokenize(corpus)

for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Everyone', ',', 'Welcome', 'to', 'the', '100', 'Day', "'s", 'of', 'Data', 'scientist', 'journey', ',', 'Stared', 'the', 'learning', 'of', 'the', 'NLP', '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Everyone',
#  ',',
#  'Welcome',
#  'to',
#  'the',
#  '100',
#  'Day',
#  "'s",
#  'of',
#  'Data',
#  'scientist',
#  'journey',
#  ',',
#  'Stared',
#  'the',
#  'learning',
#  'of',
#  'the',
#  'NLP',
#  '.']
