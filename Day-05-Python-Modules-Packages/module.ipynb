# %%
print("Modules")
# Out:
# Modules

# %%
import math

math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi

print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
from math import *

print(sqrt(20))
print(pi)
# Out:
# 4.47213595499958
# 3.141592653589793

# %%
import numpy as np

np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])
