# %%
my_list=[1,2,3,4,5]
for i in my_list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
type(my_list)
# Out:
# list

# %%
iterator=iter(my_list)
print(type(my_list))
# Out:
# <class 'list'>

# %%
next(iterator)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 next(iterator)
#
# StopIteration:

# %%
try:
    print(next(iterator))
except StopIteration:
    print("There are no elements to iterate")
# Out:
# There are no elements to iterate

# %%
my_string = "vijay"
string_iterator=iter(my_string)

print(next(string_iterator))
print(next(string_iterator))
# Out:
# v
# i
