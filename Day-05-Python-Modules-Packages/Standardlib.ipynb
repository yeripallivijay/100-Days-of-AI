# %%
print("libraries")
# Out:
# libraries

# %%
import array

arr = array.array("L",[1,2,3,4])
print(arr)
# Out:
# array('L', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import random
print(random.randint(1,10))
print(random.choice(['tiger','lion','eagle']))
# Out:
# 6
# eagle

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\VIJAY\Desktop\AI\Day-05-Python-Modules&Packages

# %%
import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
import json
data={'name':'vijay','age':23}

json_str=json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "vijay", "age": 23}
# <class 'str'>
# {'name': 'vijay', 'age': 23}
# <class 'dict'>

# %%
from datetime import datetime,timedelta

now=datetime.now()
print(now)
# Out:
# 2025-12-27 21:28:58.138587
